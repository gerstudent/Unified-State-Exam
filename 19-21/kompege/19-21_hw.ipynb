# %%
# 845

from functools import lru_cache


def moves(h):
    return h + 1, h * 2, h * 3


@lru_cache(None)
def game(h):
    if 36 <= h <= 60:
        return 'w'
    if h > 60:
        return 'p1'
    if any(game(i) == 'w' for i in moves(h)):
        return 'p1'
    if all(game(i) == 'p1' for i in moves(h)):
        return 'v1'
    if any(game(i) == 'v1' for i in moves(h)):
        return 'p2'
    if all(game(i) == 'p1' or game(i) == 'p2' for i in moves(h)):
        return 'v2'


for h in range(1, 36):
    if game(h):
        print(h, game(h))

# %%
# 1202

from functools import lru_cache

win = 59
h1 = 5


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 53):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1202

from functools import lru_cache

win = 59
h1 = 5


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 53):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 853

from functools import lru_cache

win = 77
h1 = 7


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 70):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1135

from functools import lru_cache

win = 68
h1 = 8


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a + b, b), (a, b + a)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 60):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1420

from functools import lru_cache
from math import prod

win = 63
h1 = 2


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if prod(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 32):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 853

from functools import lru_cache

win = 77
h1 = 7


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 70):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1135

from functools import lru_cache

win = 68
h1 = 8


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a + b, b), (a, b + a)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 60):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1420

from functools import lru_cache
from math import prod

win = 63
h1 = 2


def moves(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if prod(h) >= win:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 32):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def moves(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if any(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def moves(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if any(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def moves(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def moves(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in moves(h)):
        return "P1"
    if all(f(x) == "P1" for x in moves(h)):
        return "B1"
    if any(f(x) == "B1" for x in moves(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in moves(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b = h
    res = []
    if a > 0:
        res.append((a - 1, b))
    if b > 0:
        res.append((a, b - 1))
    if a > 1:
        res.append(((a + 1) // 2, b))
    if b > 1:
        res.append((a, (b + 1) // 2))
    return res


@lru_cache(None)
def g(h):
    a, b = h
    if a + b <= 20:
        return 'w'
    if any(g(x) == 'w' for x in m(h)):
        return 'p1'
    if all(g(x) == 'p1' for x in m(h)):
        return 'v1'
    if any(g(x) == 'v1' for x in m(h)):
        return 'p2'
    if all(g(x) == 'p1' or g(x) == 'p2' for x in m(h)):
        return 'v2'


a19, a20, a21 = [], [], []
for s in range(10, 100):
    cur = g((10, s))
    if cur == 'v1':
        a19.append((s, cur))
    if cur == 'p2':
        a20.append((s, cur))
    if cur == 'v2':
        a21.append((s, cur))
        
print(a19, (min(a20), max(a20)), a21, sep='\n')
# Out:
# [(21, 'v1')]
# ((22, 'p2'), (42, 'p2'))
# [(24, 'v2')]

# %%
from functools import lru_cache


def m(h):
    return h * 3, h + 1


def g(h):
    if h >= 2163:
        return 'w'
    if any(g(x) == 'w' for x in m(h)):
        return 'p1'
    if all(g(x) == 'p1' for x in m(h)):
        return 'v1'
    if any(g(x) == 'v1' for x in m(h)):
        return 'p2'
    if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
        return 'v2'


for s in range(1, 2162):
    print(s, g(s))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#      18         return 'v2'
#      21 for s in range(1, 2162):
# ---> 22     print(s, g(s))
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in <genexpr>(.0)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in <genexpr>(.0)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
#     [... skipping similar frames: <genexpr> at line 11 (469 times), g at line 11 (469 times)]
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in <genexpr>(.0)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 15, in g(h)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 15, in <genexpr>(.0)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 13, in g(h)
#      11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
# ---> 13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
#      15 if any(g(x) == 'v1' for x in m(h)):
#
# Cell In[3], line 13, in <genexpr>(.0)
#      11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
# ---> 13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
#      15 if any(g(x) == 'v1' for x in m(h)):
#
# Cell In[3], line 17, in g(h)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 17, in <genexpr>(.0)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 17, in g(h)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 17, in <genexpr>(.0)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 15, in g(h)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 15, in <genexpr>(.0)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in <genexpr>(.0)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 17, in g(h)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 17, in <genexpr>(.0)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 15, in g(h)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 15, in <genexpr>(.0)
#      13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
# ---> 15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
#      17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 17, in g(h)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 17, in <genexpr>(.0)
#      15 if any(g(x) == 'v1' for x in m(h)):
#      16     return 'p2'
# ---> 17 if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
#      18     return 'v2'
#
# Cell In[3], line 13, in g(h)
#      11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
# ---> 13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
#      15 if any(g(x) == 'v1' for x in m(h)):
#
# Cell In[3], line 13, in <genexpr>(.0)
#      11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
# ---> 13 if all(g(x) == 'p1' for x in m(h)):
#      14     return 'v1'
#      15 if any(g(x) == 'v1' for x in m(h)):
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in <genexpr>(.0)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 11, in g(h)
#       9 if h >= 2163:
#      10     return 'w'
# ---> 11 if any(g(x) == 'w' for x in m(h)):
#      12     return 'p1'
#      13 if all(g(x) == 'p1' for x in m(h)):
#
# Cell In[3], line 4, in m(h)
#       1 from functools import lru_cache
# ----> 4 def m(h):
#       5     return h * 3, h + 1
#       8 def g(h):
#
# KeyboardInterrupt:
