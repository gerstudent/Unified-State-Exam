# %%
from functools import lru_cache


def m(h):
    return h * 2, h + 1, h + 2, h + 3


@lru_cache(None)
def g(h):
    if h >= 34:
        return 'w'
    if any(g(x) == 'w' for x in m(h)):
        return 'p1'
    if all(g(x) == 'p1' for x in m(h)):
        return 'v1'
    if any(g(x) == 'v1' for x in m(h)):
        return 'p2'
    if all(g(x) == 'p1' or g(x) == 'p2' for x in m(h)):
        return 'v2'


ans19, ans20, ans21 = [], [], []
for s in range(1, 33):
    if g(s) == 'v1':
        ans19.append(s)
    if g(s) == 'p2':
        ans20.append(s)
    if g(s) == 'v2':
        ans21.append(s)

print(ans19, ans20, ans21, sep='\n')

# %%
# 845

from functools import lru_cache


def m(h):
    return h + 1, h * 2, h * 3


@lru_cache(None)
def g(h):
    if 36 <= h <= 60:
        return 'w'
    if h > 60:
        return 'p1'
    if any(g(i) == 'w' for i in m(h)):
        return 'p1'
    if all(g(i) == 'p1' for i in m(h)):
        return 'v1'
    if any(g(i) == 'v1' for i in m(h)):
        return 'p2'
    if all(g(i) == 'p1' or g(i) == 'p2' for i in m(h)):
        return 'v2'


for h in range(1, 36):
    if g(h):
        print(h, g(h))

# %%
# 1202

from functools import lru_cache

win = 59
h1 = 5


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 53):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1202

from functools import lru_cache

win = 59
h1 = 5


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 53):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 853

from functools import lru_cache

win = 77
h1 = 7


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 70):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1135

from functools import lru_cache

win = 68
h1 = 8


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a + b, b), (a, b + a)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 60):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1420

from functools import lru_cache
from math import prod

win = 63
h1 = 2


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if prod(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 32):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 853

from functools import lru_cache

win = 77
h1 = 7


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 70):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1135

from functools import lru_cache

win = 68
h1 = 8


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a + b, b), (a, b + a)


@lru_cache(None)
def f(h):
    if sum(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 60):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
# 1420

from functools import lru_cache
from math import prod

win = 63
h1 = 2


def m(h):
    a, b = h
    return (a + 1, b), (a, b + 1), (a * 2, b), (a, b * 2)


@lru_cache(None)
def f(h):
    if prod(h) >= win:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 32):
    cur = f((h1, s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if any(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if any(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b, c = h
    return (a + 3, b, c), (a, b + 3, c), (a, b, c + 3), \
        (a + 13, b, c), (a, b + 13, c), (a, b, c + 13), \
        (a + 23, b, c), (a, b + 23, c), (a, b, c + 23)


@lru_cache(None)
def f(h):
    if sum(h) >= 73:
        return "W"
    if any(f(x) == "W" for x in m(h)):
        return "P1"
    if all(f(x) == "P1" for x in m(h)):
        return "B1"
    if any(f(x) == "B1" for x in m(h)):
        return "P2"
    if all(f(x) == "P1" or f(x) == "P2" for x in m(h)):
        return "B2"


for s in range(1, 24):
    cur = f((2, s, 2 * s))
    if cur is not None:
        print(s, cur)

# %%
from functools import lru_cache


def m(h):
    a, b = h
    res = []
    if a > 0:
        res.append((a - 1, b))
    if b > 0:
        res.append((a, b - 1))
    if a > 1:
        res.append(((a + 1) // 2, b))
    if b > 1:
        res.append((a, (b + 1) // 2))
    return res


@lru_cache(None)
def g(h):
    a, b = h
    if a + b <= 20:
        return 'w'
    if any(g(x) == 'w' for x in m(h)):
        return 'p1'
    if all(g(x) == 'p1' for x in m(h)):
        return 'v1'
    if any(g(x) == 'v1' for x in m(h)):
        return 'p2'
    if all(g(x) == 'p1' or g(x) == 'p2' for x in m(h)):
        return 'v2'


a19, a20, a21 = [], [], []
for s in range(10, 100):
    cur = g((10, s))
    if cur == 'v1':
        a19.append((s, cur))
    if cur == 'p2':
        a20.append((s, cur))
    if cur == 'v2':
        a21.append((s, cur))
        
print(a19, (min(a20), max(a20)), a21, sep='\n')

# %%
from functools import lru_cache
from sys import setrecursionlimit

setrecursionlimit(200000)


def m(h):
    return h * 3, h + 1


@lru_cache(None)
def g(h):
    if h >= 2163:
        return 'w'
    if any(g(x) == 'w' for x in m(h)):
        return 'p1'
    if all(g(x) == 'p1' for x in m(h)):
        return 'v1'
    if any(g(x) == 'v1' for x in m(h)):
        return 'p2'
    if all(g(x) == 'p2' or g(x) == 'p1' for x in m(h)):
        return 'v2'


ans19, ans20, ans21 = [], [], []
for s in range(1, 2162):
    if g(s) == 'v1':
        ans19.append(s)

    if g(s) == 'p2':
        ans20.append(s)

    if g(s) == 'v2':
        ans21.append(s)

print(ans19, ans20, ans21, sep='\n')
