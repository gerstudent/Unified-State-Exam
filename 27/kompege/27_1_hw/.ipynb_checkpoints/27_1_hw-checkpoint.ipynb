# %%
for c in ['A', 'B']:
    with open(f'27{c}_2719.txt') as f:
        n = int(f.readline())
        even = odd = 0
        for i in range(n):
            x = int(f.readline())
            if x % 2 == 0:
                even += 1
            else:
                odd += 1

    print(even * (even - 1) // 2 + odd * (odd - 1) // 2, end = ' ')
# Out:
# 2459 24995121

# %%
for c in ['A', 'B']:
    with open(f'27{c}_2720.txt') as f:
        n = int(f.readline())
        k = nk = 0
        for i in range(n):
            x = int(f.readline())
            if x % 7 == 0:
                k += 1
            else:
                nk += 1
        

    print(k * nk + k * (k - 1) // 2, end = ' ')
# Out:
# 1209 13831740

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2721.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        cnt = 0
        for x, y in combinations(data, 2):
            if x * y % 65 == 0:
                cnt += 1
    print(cnt, end = ' ')

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2722.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        cnt = 0
        for x, y in combinations(data, 2):
            if x * y % 5 == 0 and (x + y) % 2 != 0:
                cnt += 1
    print(cnt, end = ' ')

# %%
for c in ['A', 'B']:
    with open(f'27{c}_2723.txt') as f:
        n = int(f.readline())
        k19 = 0
        for i in range(n):
            x = int(f.readline())
            if x % 19 == 0:
                k19 += 1
                
    print(k19 * (k19 - 1) * (k19 - 2) // 6, end = ' ')
# Out:
# 4 25808936

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2724.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        cnt = 0
        for x, y in combinations(data, 2):
            if (x + y) % 131 == 0:
                cnt += 1
    print(cnt, end = ' ')
# Out:
# 31 381543

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2725.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        cnt = 0
        for x, y in combinations(data, 2):
            if (x - y) % 69 == 0:
                cnt += 1
    print(cnt, end = ' ')
# Out:
# 61 725088

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2725.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        cnt = 0
        for x, y in combinations(data, 2):
            if (x - y) % 69 == 0:
                cnt += 1
    print(cnt, end = ' ')
# Out:
# 61 725088

# %%
for c in ['A', 'B']:
    with open(f'27{c}_2725.txt') as f:
        n = int(f.readline())
        cnt = 0
        k = [0] * 69
        for i in range(n):
            x = int(f.readline())
            k[x % 69] += 1
        
        for i in range(69):
            cnt += k[i] * (k[i] - 1) // 2
    print(cnt, end = ' ')
# Out:
# 61 725088

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2733.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        cnt = 0
        for x, y in combinations(data, 2):
            c = x > 50000 or y > 50000
            if (x + y) % 80 == 0 and c:
                cnt += 1
    print(cnt, end = ' ')
# Out:
# 48 465486

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2737.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        cnt = 0
        for x, y in combinations(data, 2):
            if (x + y) == 2000:
                cnt += 1
    print(cnt, end = ' ')
# Out:
# 1 4040

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2726.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        ans = []
        for x, y in combinations(data, 2):
            if (x + y) % 2 != 0:
                ans.append(x + y)
    print(max(ans), end = ' ')
# Out:
# 73319 133981

# %%
# эффективное решение

for c in ['A', 'B']:
    with open(f'27{c}_2726.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        even = []
        odd = []
        for i in data:
            if i % 2 == 0:
                even.append(i)
            else:
                odd.append(i)
                
        even.sort()
        odd.sort()
        mx = even[-1] + odd[-1]
    print(mx, end = ' ')
# Out:
# 73319 133981

# %%
from itertools import combinations

for c in ['A', 'B']:
    with open(f'27{c}_2728.txt') as f:
        n = int(f.readline())
        data = [int(x) for x in f.readlines()]
        
        ans = []
        for x, y in combinations(data, 2):
            n1 = x % 23 == 0 or y % 23 == 0
            if n1 and (x + y) % 2 == 0:
                ans.append(x + y)
    print(max(ans), end = ' ')
# Out:
# 65406 133892

# %%
with open('27{c}_2728.txt') as f:
    n = int(f.readline())
