# %%
# step 13 (1)

with open('24-215.txt') as f:
    s = f.readline()

s = s.replace('B', 'A').replace('C', 'A').replace('2', '1').replace('3', '1')
s = s.replace('A1A', '*').replace('A', ' ').replace('1', ' ')
print(max(len(x) for x in s.split()))

# step 15 (2)

with open('24-181.txt') as f:
    s = f.readline()

s = s.split('.')
m = 0
for i in range(len(s) - 5):
    sb = s[i] + '.' + s[i + 1] + '.' + s[i + 2] + '.' + s[i + 3] + '.' + s[i + 4] + '.' + s[i + 5]
    m = max(m, len(sb))

print(m)

# step 16 (2)

with open('24-179.txt') as f:
    s = f.readline()

cnt = 0
lst = []
for i in range(len(s) - 1):
    if s[i] + s[i + 1] == 'CB' and s[i + 3] + s[i + 4] == 'BC':
        if s[i + 2] not in 'ABF':
            cnt += 1
            let = s[i + 2]
            lst.append(let)

print(cnt)

# step 5 (2)

with open('24-1.txt') as f:
    s = f.readline()

for i in 'AEIOYU':
    s = s.replace(i, '*')

s = s.split('*')
m = 0
for i in range(len(s) - 5):
    ans = s[i] + '*' + s[i + 1] + '*' + s[i + 2] + '*' + s[i + 3] + '*' + s[i + 4] + '*' + s[i + 5]
    m = max(m, len(ans))

print(m)

# step 3 (2)

with open('24-209.txt') as f:
    s = f.readline()

lst = {'AB', 'CB', 'BC', 'BA'}
m = c = 0
i = 0
while i < len(s) - 2:
    if s[i:i + 2] in lst:
        c += 1
        i += 1
    else:
        c = 0
        i += 1
    m = max(m, c)

print(m)

# step 2 (2)

with open('24-211.txt') as f:
    s = f.readline()

lst = {'ABEC', 'BDAC', 'CAFB', 'CFBA'}
m = c = 0
i = 0
while i < len(s) - 3:
    if s[i:i + 4] in lst:
        c += 1
        i += 3
    else:
        c = 0
        i += 1
    m = max(m, c)

print(m)

# step 9 (1)

from fnmatch import fnmatch

with open('24-230.txt') as f:
    s = f.readline()

s = s.split('ZZ')
m = 0
for i in s:
    if fnmatch(i, '8???54???22'):
        m = max(m, int(i))

ans = 1
while m > 0:
    dig = m % 10
    if dig % 2 != 0:
        ans *= dig
    m //= 10

print(ans)

# step 7 (2)

with open('24-203.txt', 'r') as f:
    s = f.readline()
    count = 0
    for i in range(len(s) - 2):
        for j in range(i + 3, len(s) + 1):
            if len(set(s[i:j])) < 3:
                count += 1
            else:
                break
print(count)

# step 8 (2)

from fnmatch import fnmatch

with open('24-200.txt') as f:
    s = f.read().splitlines()

cnt = 0
lst = set()
for i in s:
    if fnmatch(i, '195.2*.?*.14'):
        lst.add(i)
        cnt += 1

print(len(lst))

# step 9 (2)

from fnmatch import fnmatch

with open('24-200.txt') as f:
    s = f.read().splitlines()

cnt = 0
lst = set()
for i in s:
    if fnmatch(i, '195.2?.1?5.14'):
        lst.add(i)
        cnt += 1

print(len(lst))

# step 11 (2)

with open('24-191.txt', 'r') as f:
    s = f.readline()

s = s.replace('A', ' A').replace('B', 'B ')
s = s.split()
cnt = 0
for c in s:
    if c[0] == 'A' and c[-1] == 'B' and len(c) >= 20 and c.count('F') == 2:
        cnt += 1

print(cnt)

# step 12 (2)

with open('24-181.txt', 'r') as f:
    s = f.readline()

for c in 'AEIOYU':
    s = s.replace(c, ' ')

ans = [len(c) for c in s.split() if c.count('.') >= 6]
print(max(ans))

with open('24_7824.txt') as f:
    s = f.readline()

s = s.replace('B', 'A').replace('C', 'A')
while 'AAA' in s:
    s = s.replace('AAA', 'AA AA')

s = s.split()
print(s)
print(len(max(s, key=len)))

with open('24_7688.txt') as f:
    s = f.readline()

s = s.replace('TXA', '@').replace('XA', '*').replace('XY', '*')
for i in set(s):
    if i not in '@*':
        s = s.replace(i, ' ')

s = s.split()
ln, mx = 0, 0
for i in s:
    ln = i.count('*') * 2 + i.count('@') * 3
    if ln > mx:
        mx = ln
        ln = 0

print(mx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 # step 13 (1)
# ----> 3 s = s.replace('B', 'A').replace('C', 'A').replace('2', '1').replace('3', '1')
#       4 s = s.replace('A11', '*').replace('A', ' ').replace('1', ' ')
#       5 print(max(len(x) for x in s.split()))
#
# NameError: name 's' is not defined
